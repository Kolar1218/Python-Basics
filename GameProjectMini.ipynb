# %%
import random
userPoints=0
systemPoints=0
tiedPoints=0

while True:
    try:
        numGames=int(input("Enter number of games you want to play\t"))
    except:
        print("Enter the integer input")

    opList=["rock","scissor","paper"]
    try:
        for rounds in range(numGames):
            print("Game",rounds+1)
            flag=1
            while flag:
                user=input("Select any 1 from the list[rock,scissor,paper]")
                if user in opList:
                    flag=0
                    break
                else:
                    print("Enter valid input")

            system=random.choice(opList)

            if system==user:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")        
                print("Game Tied")
                tiedPoints+=1
            elif user=="rock":
                if system=="paper":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    userPoints+=1

            elif user=="scissor":
                if system=="paper":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("User Won")
                    userPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("System Won")
                    systemPoints+=1

            elif user=="scissor":
                if system=="rock":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("User Won")
                    userPoints+=1
            elif user=="paper":
                if system=="scissor":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("User Won")
                    userPoints+=1  
        print("Enter the valid input") 
        print("Totoal games:",numGames)
        print("System Points",systemPoints)
        print("User Points",userPoints)
        print("Tied Points",tiedPoints) 

        if systemPoints==userPoints:
            print(">>>>>>>Game Tied<<<<<<<")
        elif systemPoints<userPoints:
            print(">>>>>>>User won the game<<<<<<<")
        else:
            print(">>>>>>>System won the gmame<<<<<<<")
        print("Do you want to play again Y/N")
        playAgain=input()
        if playAgain=='n' or playAgain=='N':
            break
    except:
        print("Enter the valid input")
print("Game ended")
# Out:
# Enter number of games you want to play	oo
# Enter the integer input
# Enter the valid input
# Enter number of games you want to play	uu
# Enter the integer input
# Enter the valid input

# %%
import random
userPoints=0
systemPoints=0
tiedPoints=0

while True:
    try:
        numGames=int(input("Enter number of games you want to play\t"))
        opList=["rock","scissor","paper"]
    
        for rounds in range(numGames):
            print("Game",rounds+1)
            flag=1
            while flag:
                user=input("Select any 1 from the list[rock,scissor,paper]")
                if user in opList:
                    flag=0
                    break
                else:
                    print("Proceed")

            system=random.choice(opList)

            if system==user:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")        
                print("Game Tied")
                tiedPoints+=1
            elif user=="rock":
                if system=="paper":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    userPoints+=1

            elif user=="scissor":
                if system=="paper":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("User Won")
                    userPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("System Won")
                    systemPoints+=1

            elif user=="scissor":
                if system=="rock":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("User Won")
                    userPoints+=1
            elif user=="paper":
                if system=="scissor":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("User Won")
                    userPoints+=1  
        print("Enter the valid input") 
        print("Totoal games:",numGames)
        print("System Points",systemPoints)
        print("User Points",userPoints)
        print("Tied Points",tiedPoints) 

        if systemPoints==userPoints:
            print(">>>>>>>Game Tied<<<<<<<")
        elif systemPoints<userPoints:
            print(">>>>>>>User won the game<<<<<<<")
        else:
            print(">>>>>>>System won the gmame<<<<<<<")
        print("Do you want to play again Y/N")
        playAgain=input()
        if playAgain=='n' or playAgain=='N':
            break
    except Exception as error:
        print("Exceptions + operations")
        print(error)
        print(type(error))
        
print("Game ended")
# Out:
# Enter number of games you want to play	'
# Exceptions + operations
# invalid literal for int() with base 10: "'"
# <class 'ValueError'>
# Enter number of games you want to play	1
# Game 1
# Select any 1 from the list[rock,scissor,paper]roc
# Proceed
# Select any 1 from the list[rock,scissor,paper]rock
# User selected	rock
# System selected	paper
# System Won
# Enter the valid input
# Totoal games: 1
# System Points 1
# User Points 0
# Tied Points 0
# >>>>>>>System won the gmame<<<<<<<
# Do you want to play again Y/N
# n
# Game ended
