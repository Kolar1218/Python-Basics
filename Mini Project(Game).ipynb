# %%
import random
numGames=int(input("Enter number of games you want to play\t"))

print("Enter the integer input")

opList=["rock","scissor","paper"]

Upoints=0
Spoints=0
tied=0
for rounds in range(numGames):
    print("Game",rounds+1)
    flag=1
    while flag:
        user=input("Select any 1 from the list[rock,scissor,paper]")
        if user in opList:
            flag=0
            break
        else:
            print("Enter valid input")     
    system=random.choice(opList)

    if system==user:
        print("Game Tied")
        tied+=1
    elif user=="rock":
        if system=="paper":
            print("System Won")
            Spoints+=1
        else:
            print("User Won")
            Upoints+=1

    elif user=="scissor":
        if system=="paper":
            print("User Won")
            Upoints+=1
        else:
            print("System Won")
            Spoints+=1

    elif user=="scissor":
        if system=="rock":
            print("System Won")
            Spoints+=1
        else:
            print("User Won")
            Upoints+=1
    elif user=="paper":
        if system=="scissor":
            print("System Won")
            Spoints+=1
        else:
            print("User Won")
            Upoints+=1  
print("Enter the valid input")
print("Totoal games:",numGames)
print("System Points",Spoints)
print("User Points",Upoints)
print("Tied Points",tied)
# Out:
# Enter number of games you want to play	2
# Enter the integer input
# Game 1
# Select any 1 from the list[rock,scissor,paper]paper
# Game Tied
# Game 2
# Select any 1 from the list[rock,scissor,paper]paper
# Game Tied
# Enter the valid input
# Totoal games: 2
# System Points 0
# User Points 0
# Tied Points 2

# %% [raw]
# =======================================================================================================
# Miniproject: (3 hours)
#
# rock paper scissor
#
# 1 player: user  2nd player: system
#
# rock + rock ==> Tie
# paper + paper ==> Tie
# scissor + scissor ==> Tie
#
# rock + scissor ==> rock
# paper + scissor ==> scissor
# rock + paper  ===> paper
#
# How to collect user input ==> input
#
# How to collect system input ==> random
#
# import random
#
# Li1 = ["rock","paper","scissor"]
#
# print(random.choice(Li1))
# print(random.choice(Li1))
# print(random.choice(Li1))
# print(random.choice(Li1))
# print(random.choice(Li1))
#
# Number of games you want to play ? collect one integer
#
# Who wins?
#
# Number of games you want to play ?  3
#
# Game 1:
# Give your input ["rock","paper","scissor"] : rock
# System input: random
#
#
# Game 2:
#
# Give your input ["rock","paper","scissor"] : rock
# System input: random
#
# Game3
#
# Give your input ["rock","paper","scissor"] : rock
# System input: random
#
# Total of number games: 3
# System points ==> 0
# User point ==> 2
# Tie ===> 1
#
# USER wins the game !!! Congrats !!!!

# %%
import random
userPoints=0
systemPoints=0
tiedPoints=0

while True:
    try:
        numGames=int(input("Enter number of games you want to play\t"))
    except:
        print("Enter the integer input")

    opList=["rock","scissor","paper"]

    for rounds in range(numGames):
        print("Game",rounds+1)
        flag=1
        while flag:
            user=input("Select any 1 from the list[rock,scissor,paper]")
            if user in opList:
                flag=0
                break
            else:
                print("Enter valid input")

        system=random.choice(opList)

        if system==user:
            print(f"User selected\t{user}")
            print(f"System selected\t{system}")        
            print("Game Tied")
            tiedPoints+=1
        elif user=="rock":
            if system=="paper":
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")
                print("System Won")
                systemPoints+=1
            else:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")  
                print("User Won")
                userPoints+=1

        elif user=="scissor":
            if system=="paper":
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")
                print("User Won")
                userPoints+=1
            else:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")  
                print("User Won")
                print("System Won")
                systemPoints+=1

        elif user=="scissor":
            if system=="rock":
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")
                print("System Won")
                systemPoints+=1
            else:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")  
                print("User Won")
                print("User Won")
                userPoints+=1
        elif user=="paper":
            if system=="scissor":
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")
                print("System Won")
                systemPoints+=1
            else:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")  
                print("User Won")
                print("User Won")
                userPoints+=1  
    print("Enter the valid input") 
    print("Totoal games:",numGames)
    print("System Points",systemPoints)
    print("User Points",userPoints)
    print("Tied Points",tiedPoints) 

    if systemPoints==userPoints:
        print(">>>>>>>Game Tied<<<<<<<")
    elif systemPoints<userPoints:
        print(">>>>>>>User won the game<<<<<<<")
    else:
        print(">>>>>>>System won the gmame<<<<<<<")
    print("You want to play again Y/N")
    playAgain=input()
    if playAgain==n or playAgain==N:
        break
    print("Game ended")
# Out:
# Enter number of games you want to play	l
# Enter the integer input
# Game 1
# Select any 1 from the list[rock,scissor,paper]l
# Enter valid input
# Select any 1 from the list[rock,scissor,paper]paper
# User selected	paper
# System selected	scissor
# System Won
# Game 2
# Select any 1 from the list[rock,scissor,paper]paper
# User selected	paper
# System selected	rock
# User Won
# User Won
# Enter the valid input
# Totoal games: 2
# System Points 1
# User Points 1
# Tied Points 0
# >>>>>>>Game Tied<<<<<<<
# You want to play again Y/N
# n
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13096/2795460494.py in <module>
#      93     print("You want to play again Y/N")
#      94     playAgain=input()
# ---> 95     if playAgain==n or playAgain==N:
#      96         break
#      97     print("Game ended")
#
# NameError: name 'n' is not defined

# %%
import random
userPoints=0
systemPoints=0
tiedPoints=0

while True:
    try:
        numGames=int(input("Enter number of games you want to play\t"))
        opList=["rock","scissor","paper"]
    
        for rounds in range(numGames):
            print("Game",rounds+1)
            flag=1
            while flag:
                user=input("Select any 1 from the list[rock,scissor,paper]")
                if user in opList:
                    flag=0
                    break
                else:
                    print("Enter valid input")

            system=random.choice(opList)

            if system==user:
                print(f"User selected\t{user}")
                print(f"System selected\t{system}")        
                print("Game Tied")
                tiedPoints+=1
            elif user=="rock":
                if system=="paper":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    userPoints+=1

            elif user=="scissor":
                if system=="paper":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("User Won")
                    userPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("System Won")
                    systemPoints+=1

            elif user=="scissor":
                if system=="rock":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("User Won")
                    userPoints+=1
            elif user=="paper":
                if system=="scissor":
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")
                    print("System Won")
                    systemPoints+=1
                else:
                    print(f"User selected\t{user}")
                    print(f"System selected\t{system}")  
                    print("User Won")
                    print("User Won")
                    userPoints+=1  
        print("Enter the valid input") 
        print("Totoal games:",numGames)
        print("System Points",systemPoints)
        print("User Points",userPoints)
        print("Tied Points",tiedPoints) 

        if systemPoints==userPoints:
            print(">>>>>>>Game Tied<<<<<<<")
        elif systemPoints<userPoints:
            print(">>>>>>>User won the game<<<<<<<")
        else:
            print(">>>>>>>System won the gmame<<<<<<<")
        print("Do you want to play again Y/N")
        playAgain=input()
        if playAgain=='n' or playAgain=='N':
            break
    except:
        print("Enter the valid input")
print("Game ended")
# Out:
# Enter number of games you want to play	0
# Enter the valid input
# Totoal games: 0
# System Points 0
# User Points 0
# Tied Points 0
# >>>>>>>Game Tied<<<<<<<
# Do you want to play again Y/N
# y
# Enter number of games you want to play	1
# Game 1
# Select any 1 from the list[rock,scissor,paper]system
# Enter valid input
# Select any 1 from the list[rock,scissor,paper]scissor
# User selected	scissor
# System selected	scissor
# Game Tied
# Enter the valid input
# Totoal games: 1
# System Points 0
# User Points 0
# Tied Points 1
# >>>>>>>Game Tied<<<<<<<
# Do you want to play again Y/N
# n
# Game ended
